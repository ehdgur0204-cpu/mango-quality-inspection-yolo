# %%
import pandas as pd

# %%
labels_df = pd.read_csv("labels_parsed.csv")
labels_df.head()
# Out:
#   split        image_name            label_file  line_no  class_id  \
# 0  test  Alternaria (110)  Alternaria (110).txt        1         0
# 1  test   Alternaria (12)   Alternaria (12).txt        1         0
# 2  test  Alternaria (145)  Alternaria (145).txt        1         0
# 3  test  Alternaria (145)  Alternaria (145).txt        2         0
# 4  test  Alternaria (145)  Alternaria (145).txt        3         0
#
#    class_name  x_center  y_center     width    height issue_type action  \
# 0  Alternaria  0.279825  0.378547  0.338071  0.495839       none   keep
# 1  Alternaria  0.412942  0.703472  0.359204  0.537159       none   keep
# 2  Alternaria  0.447338  0.618924  0.668403  0.603299       none   keep
# 3  Alternaria  0.759115  0.181424  0.481771  0.362847       none   keep
# 4  Alternaria  0.789497  0.756293  0.421007  0.487413       none   keep
#
#   reviewer note  Unnamed: 14 dataset_action  x_center_clean  y_center_clean  \
# ...
